# %% [markdown]
# <a href="https://colab.research.google.com/github/jinjin0070/dataAnalysys/blob/main/2_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_02_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC_Pandas_%EB%B0%B0%ED%8F%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
# 교재: 데이터 과학을 위한 파이썬 머신러닝(Chapter4)

# %% [markdown]
# - <a href="#04.1판다스란">04.1 판다스란</a>
# - <a href="#04.2데이터추출">04.2 데이터 추출</a>
# - <a href="#04.3그룹별집계">04.3 그룹별 집계</a>
# - <a href="#04.4병합과연결">04.4 병합과 연결</a>

# %% [markdown]
# ---------------

# %% [markdown]
# ### 라이브러리 설치

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\python\python312\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.1'

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## <a name="04.1판다스란">04.1 판다스란</a>

# %% [markdown]
# ### 1. 판다스의 개념
# - https://pandas.pydata.org/
# - 파이썬의 데이터 분석 라이브러리
# - 데이터 테이블(data table)을 다루는 도구
# - 넘파이를 사용, 판다스는 넘파이를 효율적으로 사용하기 위해 인덱싱, 연산, 전처리 등 다양한 함수 제공
# - **데이터프레임(DataFrame)** : 데이터 테이블 전체 객체
# - **시리즈(Series)** : 각 열 데이터를 다루는 객체
# - 10 minutes to pandas : https://pandas.pydata.org/docs/user_guide/10min.html

# %% [markdown]
# ### 2. 시리즈 객체
# - 피쳐 벡터(feature vector)와 같은 개념
# - 데이터프레임(DataFrame) 안에 포함된 열(colume)들을 지칭할 수 있음
# - list, dict, ndarray 등 다양한 데이터 타입이 시리즈 객체 형태로 변환되기도 함

# %% [markdown]
# ### [예제] Series 객체

# %%
# from pandas import Series
import pandas as pd
data = pd.Series([1,2,3,4,5])
print(type(data))
print(f'인덱스: {data.index}')
print(f'value: {data.values}')
data
# Out:
# <class 'pandas.core.series.Series'>
# 인덱스: RangeIndex(start=0, stop=5, step=1)
# value: [1 2 3 4 5]
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### Series 객체 생성
# - 판다스의 모든 객체는 인덱스 값을 기준으로 생성

# %%
# 딕셔너리는 키를 인덱스로 사용한다.
dict_data = {"a":1, "b":2, "c":3, "d":4, "e":5}
# data = pd.Series(dict_data, index=dict_data.keys())
data = pd.Series(dict_data)
print(data.index)
data
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# 시리즈 객체간 연산이 가능하다
data1 = pd.Series({'국어':100, '영어':90, '수학':80, '과학':100})
data2 = pd.Series({'국어':100, '영어':90, '수학':100, '과학':100})
data2 - data1
# Out:
# 국어     0
# 영어     0
# 수학    20
# 과학     0
# dtype: int64

# %%
# 데이터(element:요소) 추가/삭제가 가능하다
data1['체육'] = 100 # 데이터 추가
del data1['영어'] # 데이터 삭제
data1
# Out:
# 국어    100
# 수학     80
# 과학    100
# 체육    100
# dtype: int64

# %%
-data

# %%
dates = pd.date_range("20240101", periods=6)
type(dates)
dates

dates = pd.date_range("20240101", periods=6, freq='M')
dates
# Out:
# C:\Users\501-11\AppData\Local\Temp\ipykernel_6612\1378861626.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range("20240101", periods=6, freq='M')
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# - period_range
# - https://padas.pydata.org/pandas-docs/stable/user_guide/timeseries.heml#offset-aliases

# %%
dates = pd.period_range(start='2014', end='2024', freq='Y')
# dates = pd.period_range(start='2014', end='2024', freq = 'M')
dates
# Out:
# PeriodIndex(['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#              '2022', '2023', '2024'],
#             dtype='period[Y-DEC]')

# %% [markdown]
# ------------------

# %% [markdown]
# ### 3. 데이터프레임 객체
# - 데이터 테이블 전체를 지칭하는 객체
# - 넘파이 배열의 특성을 그대로 가짐
# - 인덱싱 : 열과 행 각각 사용하여 하나의 데이터에 접근

# %% [markdown]
# ### [예제] Pandas로 다양한 파일 읽어오기

# %% [markdown]
# #### 1.txt 데이터 Pandas DataFrame으로 나타내기

# %%
import pandas as pd

dir = './data/'
df = pd.read_table(f'{dir}book.txt', sep=',',names=['제목','영어제목','저자','언어','출판년도'])
df
# Out:
#             제목                      영어제목            저자    언어         출판년도
# 0     두 도시 이야기      A Tale of Two Cities        찰스 디킨스    영어         1859
# 1        어린 왕자           Le Petit Prince   앙투안 드 생텍쥐페리  프랑스어         1943
# 2       반지의 제왕     The Lord of the Rings   J. R. R. 톨킨    영어  1954 ~ 1955
# 3  그리고 아무도 없었다  And Then There Were None      애거사 크리스티    영어         1939
# 4           호빗                The Hobbit   J. R. R. 톨킨    영어         1937

# %% [markdown]
# #### 2.csv 데이터 Pandas DataFrame으로 나타내기

# %%
filename = './data/인구밀도.csv'
df = pd.read_csv(filename, encoding='cp949')
df
# Out:
#       행정구역별     2020     2021     2022
# 0        전국    516.2    515.2    514.6
# 1     서울특별시  15839.0  15650.1  15560.7
# 2     부산광역시   4348.9   4316.4   4272.8
# 3     대구광역시   2728.6   2702.2   2673.7
# 4     인천광역시   2765.1   2772.8   2801.3
# 5     광주광역시   2948.5   2944.0   2931.9
# 6     대전광역시   2758.1   2742.8   2730.7
# 7     울산광역시   1069.0   1055.0   1044.9
# 8   세종특별자치시    761.3    787.7    822.9
# 9       경기도   1325.3   1338.9   1344.9
# 10      강원도     90.4     90.4     90.8
# 11     충청북도    220.3    219.4    219.4
# 12     충청남도    264.0    263.8    265.9
# 13     전라북도    223.4    221.4    219.8
# 14     전라남도    144.9    143.9    143.3
# 15     경상북도    138.9    138.4    137.7
# 16     경상남도    316.2    313.6    311.2
# 17  제주특별자치도    362.6    363.8    365.6

# %% [markdown]
# #### 3.Excel 시트 Pandas DataFrame으로 나타내기

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#    ---------------------------------------  245.8/250.0 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 3.9 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %% [markdown]
# ##### 1.전체 시트(sheet) 가져오기

# %%
import pandas as pd

# 전체 시트 가져오기
# 시트가 여러개 일 경우 딕셔너리 형태로 나타난다.
filename = './data/인구밀도.xlsx'
df = pd.read_excel(filename, sheet_name = none) #전체->시트가 여러개 일 경우 딕셔너리
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       3 # 전체 시트 가져오기
#       4 # 시트가 여러개 일 경우 딕셔너리 형태로 나타난다.
#       5 filename = './data/인구밀도.xlsx'
# ----> 6 df = pd.read_excel(filename, sheet_name=none) #전체->시트가 여러개 일 경우 딕셔너리
#       7 df
#
# NameError: name 'none' is not defined

# %% [markdown]
# ##### 2.특정 시트(sheet) 가져오기

# %%
# 특정 시트 가져오기
import pandas as pd
filename = './data/인구밀도.xlsx'
df = pd.read_excel(filename, sheet_name='인구밀도2') #특정시트 시정
df.head()
df.tail()
df
# Out:
#       행정구역별     2023     2024     2025
# 0        전국    516.2    515.2    514.6
# 1     서울특별시  15839.0  15650.1  15560.7
# 2     부산광역시   4348.9   4316.4   4272.8
# 3     대구광역시   2728.6   2702.2   2673.7
# 4     인천광역시   2765.1   2772.8   2801.3
# 5     광주광역시   2948.5   2944.0   2931.9
# 6     대전광역시   2758.1   2742.8   2730.7
# 7     울산광역시   1069.0   1055.0   1044.9
# 8   세종특별자치시    761.3    787.7    822.9
# 9       경기도   1325.3   1338.9   1344.9
# 10      강원도     90.4     90.4     90.8
# 11     충청북도    220.3    219.4    219.4
# 12     충청남도    264.0    263.8    265.9
# 13     전라북도    223.4    221.4    219.8
# 14     전라남도    144.9    143.9    143.3
# 15     경상북도    138.9    138.4    137.7
# 16     경상남도    316.2    313.6    311.2
# 17  제주특별자치도    362.6    363.8    365.6

# %% [markdown]
# ##### 3.여러 시트(sheet) 가져오기

# %%
# 여러 시트 가져오기: 시트 이름으로 가져오기
df = pd.read_excel(filename, sheet_name=[1,'인구밀도'])
df
#df.to_excel(파일이름)
# Out:
# {1:       행정구역별     2023     2024     2025
#  0        전국    516.2    515.2    514.6
#  1     서울특별시  15839.0  15650.1  15560.7
#  2     부산광역시   4348.9   4316.4   4272.8
#  3     대구광역시   2728.6   2702.2   2673.7
#  4     인천광역시   2765.1   2772.8   2801.3
#  5     광주광역시   2948.5   2944.0   2931.9
#  6     대전광역시   2758.1   2742.8   2730.7
#  7     울산광역시   1069.0   1055.0   1044.9
#  8   세종특별자치시    761.3    787.7    822.9
#  9       경기도   1325.3   1338.9   1344.9
#  10      강원도     90.4     90.4     90.8
#  11     충청북도    220.3    219.4    219.4
#  12     충청남도    264.0    263.8    265.9
#  13     전라북도    223.4    221.4    219.8
#  14     전라남도    144.9    143.9    143.3
#  15     경상북도    138.9    138.4    137.7
#  16     경상남도    316.2    313.6    311.2
#  17  제주특별자치도    362.6    363.8    365.6,
#  '인구밀도':       행정구역별     2020     2021     2022
#  0        전국    516.2    515.2    514.6
#  1     서울특별시  15839.0  15650.1  15560.7
#  2     부산광역시   4348.9   4316.4   4272.8
#  3     대구광역시   2728.6   2702.2   2673.7
#  4     인천광역시   2765.1   2772.8   2801.3
#  5     광주광역시   2948.5   2944.0   2931.9
#  6     대전광역시   2758.1   2742.8   2730.7
#  7     울산광역시   1069.0   1055.0   1044.9
#  8   세종특별자치시    761.3    787.7    822.9
#  9       경기도   1325.3   1338.9   1344.9
#  10      강원도     90.4     90.4     90.8
#  11     충청북도    220.3    219.4    219.4
#  12     충청남도    264.0    263.8    265.9
#  13     전라북도    223.4    221.4    219.8
#  14     전라남도    144.9    143.9    143.3
#  15     경상북도    138.9    138.4    137.7
#  16     경상남도    316.2    313.6    311.2
#  17  제주특별자치도    362.6    363.8    365.6}

# %%
# 여러 시트 가져오기: 시트 번호로 가져오기 (0번부터 시작)

# %% [markdown]
# #### 4.Remote URL의 CSV 데이터 Pandas DataFrame으로 나타내기

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

df = pd.read_csv(url, header=None)
# df =pd.read_csv(url, columns=[칼럼1,칼럼2...])
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 머신러닝 라이브러리(scikit=Learn)
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.1 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.6 MB 21.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.6 MB 27.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.6/10.6 MB 42.3 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 50.4 MB/s eta 0:00:00
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    --------------------------------------- 301.2/301.2 kB 19.4 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl (45.9 MB)
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---- ----------------------------------- 5.4/45.9 MB 114.4 MB/s eta 0:00:01
#    --------- ------------------------------ 10.9/45.9 MB 108.8 MB/s eta 0:00:01
#    -------------- ------------------------- 16.6/45.9 MB 131.2 MB/s eta 0:00:01
#    ------------------- -------------------- 22.4/45.9 MB 131.2 MB/s eta 0:00:01
#    ------------------------ --------------- 28.2/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.3/45.9 MB 108.8 MB/s eta 0:00:01
#    -------------------------------- ------- 37.7/45.9 MB 108.8 MB/s eta 0:00:01
#    ------------------------------------- -- 42.8/45.9 MB 93.0 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 45.9/45.9 MB 36.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris

df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

print("target : {iris['target']}")
print("target_names : {iris['target_names']}")
df['result'] = iris['target']
df['result_name'] = iris['target_names'][iris.target]
# df['result_name'] = iris.target_names[iris.target]
df
# Out:
# target : {iris['target']}
# target_names : {iris['target_names']}
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      result result_name
# 0         0      setosa
# 1         0      setosa
# 2         0      setosa
# 3         0      setosa
# 4         0      setosa
# ..      ...         ...
# 145       2   virginica
# 146       2   virginica
# 147       2   virginica
# 148       2   virginica
# 149       2   virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### [실습문제] 통계청 인구정보 가져오기

# %%
import pandas as pd
df = pd.read_csv("인구밀도_인구주택총조사기준__20240418110603.csv", encoding='utf-8')

df['행정구역별'] #컬럼 한 개:시리즈 객체
df.head(10)     # 앞에서부터 10개보기
df.tail(10)     # 뒤에서부터 10개보기
df.iloc[2:5, :] # iloc[행,열] -> 인덱스로 접근
df.loc[[2,3],['2021','2022']]
# Out:
#      2021    2022
# 2  4316.4  4272.8
# 3  2702.2  2673.7

# %% [markdown]
# ### 1. 데이터프레임 생성
# - 2차원 리스트 타입으로 만들기
# - 딕셔너리 타입으로 만들기 :  키(key)는 열 이름, 값(value)은 시퀀스형 데이터 타입을 넣어 각 열의 데이터로 만듦

# %%
# 2차원 리스트 타입으로 DataFrame 만들기
raw_data = [['Jason','Miller', 42, 'San Francisco'],
            ['Molly', 'Jacobson', 52, 'Baltimore'],
            ['Tina', 'Ali', 36, 'Miami'],
            ['Jake', 'Milner', 24, 'Douglas'],
            ['Amy', 'Cooze', 73, 'Boston']]
df = pd.DataFrame(raw_data)
df
# Out:
#        0         1   2              3
# 0  Jason    Miller  42  San Francisco
# 1  Molly  Jacobson  52      Baltimore
# 2   Tina       Ali  36          Miami
# 3   Jake    Milner  24        Douglas
# 4    Amy     Cooze  73         Boston

# %%
# 딕셔너리 타입으로 DataFrame 만들기
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'age': [42, 52, 36, 24, 73],
            'city': ['San Francisco', 'Baltimore', 'Miami', 'Douglas', 'Boston']}

df = pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  age           city
# 0      Jason    Miller   42  San Francisco
# 1      Molly  Jacobson   52      Baltimore
# 2       Tina       Ali   36          Miami
# 3       Jake    Milner   24        Douglas
# 4        Amy     Cooze   73         Boston

# %% [markdown]
# ### 2. 데이터프레임의 열 다루기

# %%
# 데이터 생성시, 딕셔너리 데이터에서 열(Key) 이름을 한정하면 해당 열만 추출
df = pd.DataFrame(raw_data, columns=["first_name","age"])
df
# Out:
#   first_name  age
# 0      Jason   42
# 1      Molly   52
# 2       Tina   36
# 3       Jake   24
# 4        Amy   73

# %%
# 데이터가 존재하지 않는 열을 추가하면 해당 열에는 NaN 값들 추가
df = pd.DataFrame(raw_data, columns=["first_name","age","last_name","city","hp"])
df
# Out:
#   first_name  age last_name           city   hp
# 0      Jason   42    Miller  San Francisco  NaN
# 1      Molly   52  Jacobson      Baltimore  NaN
# 2       Tina   36       Ali          Miami  NaN
# 3       Jake   24    Milner        Douglas  NaN
# 4        Amy   73     Cooze         Boston  NaN

# %% [markdown]
# -----------------

# %% [markdown]
# ## <a name="04.2데이터추출">04.2 데이터 추출</a>

# %% [markdown]
# ### 1. 데이터 로딩

# %%
filename = './data/excel-comp-data.xlsx'
df = pd.read_excel(filename)
df.head()
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# 1                      1311 Alvis Tunnel      Port Khadijah  NorthCarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           Iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          Maine
# 4                    7274 Marissa Common    Shanahanchester     California
# 5                   89403 Casimer Spring       Jeremieburgh       Arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     Mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    RhodeIsland
# 8                       26739 Grant Lock    Lake Juliannton   Pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          Idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       Tenessee
# 11              18115 Olivine Throughway      Norbertomouth    NorthDakota
# 12                       182 Bertie Road        East Davian           Iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    RhodeIsland
# 14                 8917 Bergstrom Meadow    Kathryneborough       Delaware
#
#     postal-code     Jan     Feb     Mar
# 0         28752   10000   62000   35000
# 1         38365   95000   45000   35000
# 2         76517   91000  120000   35000
# 3         46021   45000  120000   10000
# 4         49681  162000  120000   35000
# 5         62785  150000  120000   35000
# 6         18008   62000  120000   70000
# 7         53461  145000   95000   35000
# 8         64415   70000   95000   35000
# 9         46308   70000  120000   35000
# 10        47743   45000  120000   55000
# 11        31415  150000   10000  162000
# 12        72686  162000  120000   35000
# 13        31919   55000  120000   35000
# 14        27933  150000  120000   70000

# %% [markdown]
# ### 2. 열 이름을 사용한 데이터 추출

# %%
# 열 이름을 리스트 형태로 넣어 호출
df[['account', 'name', 'city']].head()
# Out:
#    account                         name             city
# 0   211829   Kerluke, Koepp and Hilpert       New Jaycob
# 1   320563               Walter-Trantow    Port Khadijah
# 2   648336   Bashirian, Kunde and Price   New Lilianland
# 3   109996  D'Amore, Gleichner and Bode       Hyattburgh
# 4   121213                Bauch-Goldner  Shanahanchester

# %% [markdown]
# ### 3. 행 번호를 사용한 데이터 추출

# %%
# 인덱스 번호로 호출
df[:3]
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %% [markdown]
# ### 4. 행과 열을 모두 사용한 데이터 추출

# %%
# 열 이름, 인덱스 번호 둘 다 사용해서 호출
df[['account', 'name', 'city']][:3]
# Out:
#    account                        name            city
# 0   211829  Kerluke, Koepp and Hilpert      New Jaycob
# 1   320563              Walter-Trantow   Port Khadijah
# 2   648336  Bashirian, Kunde and Price  New Lilianland

# %%
# 인덱스 변경하기
df.index = df['account']
del df['account']
df
# Out:
#                                      name  \
# account
# 211829         Kerluke, Koepp and Hilpert
# 320563                     Walter-Trantow
# 648336         Bashirian, Kunde and Price
# 109996        D'Amore, Gleichner and Bode
# 121213                      Bauch-Goldner
# 132971   Williamson, Schumm and Hettinger
# 145068                         Casper LLC
# 205217                   Kovacek-Johnston
# 209744                     Champlin-Morar
# 212303                     Gerhold-Maggio
# 214098        Goodwin, Homenick and Jerde
# 231907                         Hahn-Moore
# 242368       Frami, Anderson and Donnelly
# 268755                        Walsh-Haley
# 273274                      McDermott PLC
#
#                                        street               city  \
# account
# 211829                     34456 Sean Highway         New Jaycob
# 320563                      1311 Alvis Tunnel      Port Khadijah
# 648336   62184 Schamberger Underpass Apt. 231     New Lilianland
# 109996            155 Fadel Crescent Apt. 144         Hyattburgh
# 121213                    7274 Marissa Common    Shanahanchester
# 132971                   89403 Casimer Spring       Jeremieburgh
# 145068           340 Consuela Bridge Apt. 400  Lake Gabriellaton
# 205217           91971 Cronin Vista Suite 601         Deronville
# 209744                       26739 Grant Lock    Lake Juliannton
# 212303              366 Maggio Grove Apt. 998          North Ras
# 214098              649 Cierra Forks Apt. 078           Rosaberg
# 231907               18115 Olivine Throughway      Norbertomouth
# 242368                        182 Bertie Road        East Davian
# 268755                   2624 Beatty Parkways       Goodwinmouth
# 273274                  8917 Bergstrom Meadow    Kathryneborough
#
#                  state  postal-code     Jan     Feb     Mar
# account
# 211829           Texas        28752   10000   62000   35000
# 320563   NorthCarolina        38365   95000   45000   35000
# 648336            Iowa        76517   91000  120000   35000
# 109996           Maine        46021   45000  120000   10000
# 121213      California        49681  162000  120000   35000
# 132971        Arkansas        62785  150000  120000   35000
# 145068      Mississipi        18008   62000  120000   70000
# 205217     RhodeIsland        53461  145000   95000   35000
# 209744    Pennsylvania        64415   70000   95000   35000
# 212303           Idaho        46308   70000  120000   35000
# 214098        Tenessee        47743   45000  120000   55000
# 231907     NorthDakota        31415  150000   10000  162000
# 242368            Iowa        72686  162000  120000   35000
# 268755     RhodeIsland        31919   55000  120000   35000
# 273274        Delaware        27933  150000  120000   70000

# %%
# loc 함수 : 인덱스 이름과 열 이름으로 데이터 추출
df.loc[:648336, ['name','city']]
# Out:
#                                name            city
# account
# 211829   Kerluke, Koepp and Hilpert      New Jaycob
# 320563               Walter-Trantow   Port Khadijah
# 648336   Bashirian, Kunde and Price  New Lilianland

# %%
# iloc 함수 :  인덱스 번호로만 데이터 호출
df.iloc[2:4, 2:4]
# Out:
#                    city  state
# account
# 648336   New Lilianland   Iowa
# 109996       Hyattburgh  Maine

# %% [markdown]
# ### 5.새로운 인덱스 할당

# %%
# reset_index 함수로 새로운 인덱스 할당된 객체 생성
df_new = df.reset_index()
df_new.head(3)
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %% [markdown]
# ### 6. drop 함수

# %%
# drop 함수 : 특정 열이나 행을 삭제한 객체를 반환
# 컬럼삭제
# df_new.drop('street', axis=1, inplace=True) # 1개 컬럼 삭제
df_new.drop(['city', 'state'], axis=1, inplace=True) # 여러개 컬럼 삭제
df_new
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street  postal-code     Jan     Feb     Mar
# 0                     34456 Sean Highway        28752   10000   62000   35000
# 1                      1311 Alvis Tunnel        38365   95000   45000   35000
# 2   62184 Schamberger Underpass Apt. 231        76517   91000  120000   35000
# 3            155 Fadel Crescent Apt. 144        46021   45000  120000   10000
# 4                    7274 Marissa Common        49681  162000  120000   35000
# 5                   89403 Casimer Spring        62785  150000  120000   35000
# 6           340 Consuela Bridge Apt. 400        18008   62000  120000   70000
# 7           91971 Cronin Vista Suite 601        53461  145000   95000   35000
# 8                       26739 Grant Lock        64415   70000   95000   35000
# 9              366 Maggio Grove Apt. 998        46308   70000  120000   35000
# 10             649 Cierra Forks Apt. 078        47743   45000  120000   55000
# 11              18115 Olivine Throughway        31415  150000   10000  162000
# 12                       182 Bertie Road        72686  162000  120000   35000
# 13                  2624 Beatty Parkways        31919   55000  120000   35000
# 14                 8917 Bergstrom Meadow        27933  150000  120000   70000

# %% [markdown]
# ------------------------

# %%
# 행 삭제(axis=0 : default)
# df_new.drop(4, inplace=True)
# df_new.drop(0, axis=0, inplace=True)
df_new.drop([2,5,6], axis=0, inplace=True)
df_new
# Out:
#     account                          name                        street  \
# 1    320563                Walter-Trantow             1311 Alvis Tunnel
# 3    109996   D'Amore, Gleichner and Bode   155 Fadel Crescent Apt. 144
# 7    205217              Kovacek-Johnston  91971 Cronin Vista Suite 601
# 8    209744                Champlin-Morar              26739 Grant Lock
# 9    212303                Gerhold-Maggio     366 Maggio Grove Apt. 998
# 10   214098   Goodwin, Homenick and Jerde     649 Cierra Forks Apt. 078
# 11   231907                    Hahn-Moore      18115 Olivine Throughway
# 12   242368  Frami, Anderson and Donnelly               182 Bertie Road
# 13   268755                   Walsh-Haley          2624 Beatty Parkways
# 14   273274                 McDermott PLC         8917 Bergstrom Meadow
#
#     postal-code     Jan     Feb     Mar
# 1         38365   95000   45000   35000
# 3         46021   45000  120000   10000
# 7         53461  145000   95000   35000
# 8         64415   70000   95000   35000
# 9         46308   70000  120000   35000
# 10        47743   45000  120000   55000
# 11        31415  150000   10000  162000
# 12        72686  162000  120000   35000
# 13        31919   55000  120000   35000
# 14        27933  150000  120000   70000

# %% [markdown]
# ## <a name="04.3그룹별집계">04.3 그룹별 집계</a>

# %% [markdown]
# ### 1. 그룹별 집계의 개념
# - 그룹별 집계(groupby) : 데이터로부터 동일한 객체를 가진 데이터만 따로 뽑아 기술통계 데이터를 추출
# - 엑셀의 피봇테이블(pivot table) 기능과 비슷
# - groupby 명령어는 분할→적용→결합 과정을 거침
#  - - 분할(split) : 같은 종류의 데이터끼리 나누는 기능 <br>
#  - - 적용(apply) : 데이터 블록마다 sum, count, mean 등 연산 적용
#  - - 결합(combine) : 연산 함수가 적용된 각 블록들을 합침

# %% [markdown]
# ### 2. 그룹별 집계 사용하기

# %%
# 그룹별 집계의 기본형
data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings','kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
            'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
            'Year': [2014, 2015, 2014, 2015, 2014, 2015, 2016, 2017, 2016, 2014, 2015, 2017],
            'Points': [876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(data)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
# 그룹별 집계의 기본형
# Team별 그룹하여 Points의 합계 구하기
df.groupby("Team")["Points"].sum()
# Out:
# Team
# Devils    1536
# Kings     2285
# Riders    3049
# Royals    1505
# kings      812
# Name: Points, dtype: int64

# %%
# 멀티 인덱스 그룹별 집계
# - 한 개 이상의 열을 기준으로 그룹별 집계를 실행
df_group = df.groupby(["Team","Year"])["Points"].sum()
#df_group.to_csv('팀별그룹핑.csv')
df_group
# Out:
# Team    Year
# Devils  2014    863
#         2015    673
# Kings   2014    741
#         2016    756
#         2017    788
# Riders  2014    876
#         2015    789
#         2016    694
#         2017    690
# Royals  2014    701
#         2015    804
# kings   2015    812
# Name: Points, dtype: int64

# %%
# 멀티 인덱스
# - 한 개 이상의 열로 그룹별 집계 수행하면 여러 열이 모두 인덱스로 반환됨
df_group = df.groupby(["Team","Year"])["Points"].sum()
df_group.index
# Out:
# MultiIndex([('Devils', 2014),
#             ('Devils', 2015),
#             ( 'Kings', 2014),
#             ( 'Kings', 2016),
#             ( 'Kings', 2017),
#             ('Riders', 2014),
#             ('Riders', 2015),
#             ('Riders', 2016),
#             ('Riders', 2017),
#             ('Royals', 2014),
#             ('Royals', 2015),
#             ( 'kings', 2015)],
#            names=['Team', 'Year'])

# %%
# - swaplevel 함수로 인덱스 간 레벨을 변경
# - sort_index 함수로 첫 번째 인덱스를 기준으로 데이터 재정렬
df_group.swaplevel().sort_index()
# Out:
# Year  Team
# 2014  Devils    863
#       Kings     741
#       Riders    876
#       Royals    701
# 2015  Devils    673
#       Riders    789
#       Royals    804
#       kings     812
# 2016  Kings     756
#       Riders    694
# 2017  Kings     788
#       Riders    690
# Name: Points, dtype: int64

# %% [markdown]
# ### 3. 그룹화된 상태
# - 그룹화된(grouped) 상태 : 분할→적용→결합 중에서 분할까지만 이루어진 상태
# - get_group 함수 : 해당 키 값을 기준으로 분할된 데이터프레임 객체를 확인

# %%
a = df.groupby("Team")
a['Points'].sum()
# Out:
# Team
# Devils    1536
# Kings     2285
# Riders    3049
# Royals    1505
# kings      812
# Name: Points, dtype: int64

# %% [markdown]
# - **집계(aggregation)** : 요약된 통계 정보를 추출

# %%
df.groupby('Team').aggregate(min)
# Out:
#         Rank  Year  Points
# Team
# Devils     2  2014     673
# Kings      1  2014     741
# Riders     1  2014     690
# Royals     1  2014     701
# kings      4  2015     812

# %%
# 집계(aggregation) : 요약된 통계 정보를 추출
df.groupby('Team').agg(min)
# Out:
# C:\Users\501-11\AppData\Local\Temp\ipykernel_21776\58036681.py:2: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('Team').agg(min)
#         Rank  Year  Points
# Team
# Devils     2  2014     673
# Kings      1  2014     741
# Riders     1  2014     690
# Royals     1  2014     701
# kings      4  2015     812

# %%
df.groupby('Team')['Points'].agg([sum,max])
df.groupby('Team')['Points'].agg(['sum','max'])
df.groupby('Team')['Points'].agg(**{'합계': sum ,'최고': max})
# Out:
#           합계   최고
# Team
# Devils  1536  863
# Kings   2285  788
# Riders  3049  876
# Royals  1505  804
# kings    812  812

# %% [markdown]
# - **필터(filter)** : 특정 조건으로 데이터를 검색

# %%
# 필터
# Team별 레코드 개수 3개 이상인 Team
# Team별 Points의 최고값이 800이상인 Team
df.groupby('Team').filter(lambda x:len(x) >= 3)
df.groupby('Team').filter(lambda x:x['Points'].max() >= 800
                          )
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %% [markdown]
# -----------------

# %% [markdown]
# ## <a name="04.4병합과연결">04.4 병합과 연결</a>

# %% [markdown]
# ### 1. 병합
# 병합(merge) : 두 개의 데이터를 특정 기준한 기준을 가지고 하나로 통합하는 작업

# %%
raw_data = {'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
            'test_score': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
raw_data = {'subject_id': ['4', '5', '6', '7', '8'],
            'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
            'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

df_right = pd.DataFrame(raw_data)
df_right
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# 내부 조인: 양쪽의 교집합 데이터를 통합
pd.marge(left=df_left, right=df_right, on='subject_id', how='inner')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-1061c1025301> in <cell line: 2>()
#       1 # 내부 조인: 양쪽의 교집합 데이터를 통합
# ----> 2 pd.marge(left=df_left, right=df_right, on='subject_id', how='inner')
#
# AttributeError: module 'pandas' has no attribute 'marge'

# %%
# 왼쪽 조인, 오른쪽 조인

# %%
# 완전 조인

# %% [markdown]
# ### 2. 연결(concatenate)

# %%
# 디렉토리에서 파일명이 sales 가 포함된 파일명 가져오기



# 파일 Pandas DataFrame으로 읽어오기


# 파일 병합하기
pd.concat([df_left, df_right])
pd.concat([df_right, df_left])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-7419f210fd83> in <cell line: 9>()
#       7
#       8 # 파일 병합하기
# ----> 9 pd.concat([df_left, df_right])
#      10 pd.concat([df_right, df_left])
#
# NameError: name 'df_left' is not defined

# %%
 import pandas as pd
 df = pd.read_csv('./인구밀도_인구주택총조사기준__20240418110603.csv')
 df.head(2)
# Out:
#    행정구역별     2020     2021     2022
# 0     전국    516.2    515.2    514.6
# 1  서울특별시  15839.0  15650.1  15560.7

# %%
df.query("행정구역별 == '서울특별시'")
df.query("행정구역별 in ('서울특별시','경기도') and `2021` > 10000 ")
# Out:
#    행정구역별     2020     2021     2022
# 1  서울특별시  15839.0  15650.1  15560.7

# %%
# pandas/DataFreame에서 유용하게 사용하는 함수
df.info() # 데이터의 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역별   18 non-null     object
#  1   2020    18 non-null     float64
#  2   2021    18 non-null     float64
#  3   2022    18 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 704.0+ bytes

# %%
df.describe() # 데이터의 기술통계 정보
# Out:
#                2020          2021          2022
# count     18.000000     18.000000     18.000000
# mean    2045.594444   2032.211111   2025.116667
# std     3678.648378   3635.094546   3612.959623
# min       90.400000     90.400000     90.800000
# 25%      233.550000    232.000000    231.325000
# 50%      638.750000    651.450000    668.750000
# 75%     2750.725000   2732.650000   2716.450000
# max    15839.000000  15650.100000  15560.700000

# %%
# (행정구역별) 칼럼 삭제
df.index = df['행정구역별']
del df['행정구역별']
df.drop('행정구역별', axis=1, inplace=True)
df

# %%
df.index = df['행정구역별']
del df['행정구역별']
df.drop('행정구역별', axis=1, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4430256bb45d> in <cell line: 3>()
#       1 df.index = df['행정구역별']
#       2 del df['행정구역별']
# ----> 3 df.drop('행정구역별', axis=1, inplace=True)
#       4 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['행정구역별'] not found in axis"

# %%
# 행-->열 변환
df_t = df.T
df_t
# Out:
# 행정구역별     전국    서울특별시   부산광역시   대구광역시   인천광역시   광주광역시   대전광역시   울산광역시  \
# 2020   516.2  15839.0  4348.9  2728.6  2765.1  2948.5  2758.1  1069.0
# 2021   515.2  15650.1  4316.4  2702.2  2772.8  2944.0  2742.8  1055.0
# 2022   514.6  15560.7  4272.8  2673.7  2801.3  2931.9  2730.7  1044.9
#
# 행정구역별  세종특별자치시     경기도   강원도   충청북도   충청남도   전라북도   전라남도   경상북도   경상남도  \
# 2020     761.3  1325.3  90.4  220.3  264.0  223.4  144.9  138.9  316.2
# 2021     787.7  1338.9  90.4  219.4  263.8  221.4  143.9  138.4  313.6
# 2022     822.9  1344.9  90.8  219.4  265.9  219.8  143.3  137.7  311.2
#
# 행정구역별  제주특별자치도
# 2020     362.6
# 2021     363.8
# 2022     365.6

# %%
df.groupby('행정구역별')['2020'].sum()
# Out:
# 행정구역별
# 강원도           90.4
# 경기도         1325.3
# 경상남도         316.2
# 경상북도         138.9
# 광주광역시       2948.5
# 대구광역시       2728.6
# 대전광역시       2758.1
# 부산광역시       4348.9
# 서울특별시      15839.0
# 세종특별자치시      761.3
# 울산광역시       1069.0
# 인천광역시       2765.1
# 전국           516.2
# 전라남도         144.9
# 전라북도         223.4
# 제주특별자치도      362.6
# 충청남도         264.0
# 충청북도         220.3
# Name: 2020, dtype: float64
